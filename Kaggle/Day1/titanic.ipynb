# %%
import numpy as np 
import pandas as pd
# import matplotlib as mplt
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df_train=pd.read_csv("data/train.csv") 
df_test =pd.read_csv("data/test.csv") 

train_eda = df_train.drop(["Name","Cabin","Ticket"],axis=1)
train_eda.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Fare             0
# Embarked         2
# dtype: int64

# %%
plt.figure(figsize=(10,8))
sb.heatmap(data = train_eda.corr(), annot = True, cmap = 'Blues')
plt.show()

# %%
train_eda.info()
# sns.boxplot(x=train_eda["Fare"])
# sns.boxplot(x=train_eda["Pclass"])
# print(train_eda["Pclass"].mean())
# print(train_eda["Pclass"].median())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Sex          891 non-null    object
#  4   Age          714 non-null    float64
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Fare         891 non-null    float64
#  8   Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(2)
# memory usage: 62.8+ KB

# %%
print(train_eda.isnull().sum())
train_fin = train_eda.dropna()
# print(train_fin.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Fare             0
# Embarked         2
# dtype: int64
